# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/home/giodsubuntu/challenge_immo_eliza_analysis/data/20220208_Final_result.csv")
df = df.drop_duplicates(['Immoweb ID'], keep='last')

# %%
sns.boxplot (x=df["price/m2"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price/m2'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sns.boxplot(x=df['Living area'])
# Out:
# <AxesSubplot:xlabel='Living area'>

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['Living area'], df['property sub-type'])
ax.set_xlabel('Living area')
ax.set_ylabel('Type of property')
plt.show()

# %%
df = df[df['property sub-type'] != "APARTMENT_BLOCK"]

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['Living area'], df['property sub-type'])
ax.set_xlabel('Living area')
ax.set_ylabel('Type of property')
plt.show()
